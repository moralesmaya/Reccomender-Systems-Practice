# %% [markdown]
# # Recommender Systems

# %%
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %% [markdown]
# ## Loading in  `movies.csv` and `ratings.csv`
# ---
#
# I'll be using the [MovieLens](https://grouplens.org/datasets/movielens/) dataset for building our recommendation engine. There are two CSVs (`movies.csv` and `ratings.csv`) that I'll eventually inner join.

# %%
#
movies = pd.read_csv('ml-latest-small/movies.csv')

ratings = pd.read_csv('ml-latest-small/ratings.csv')

# %% [markdown]
# ## Drop unnecessary columns
# ---
#
# I don't need the `timestamp` column from `ratings`, nor will we need the `genres` column from `movies`.

# %%
ratings.drop('timestamp', axis =1, inplace = True)
movies.drop('genres', axis =1, inplace = True)

# %% [markdown]
# ## Merge `movies` and `ratings`
# ---

# %%
#merge` to **inner join** `movies` with `ratings` on the `movieId` column.

df = pd.merge(ratings, movies, on = 'movieId')

df.shape
# Out:
# (100836, 4)

# %% [markdown]
# ## Building a pivot table
# ---
#
# Because I'm creating an item-based collaborative recommender (where item in this case is our movies), I'll set up our pivot table as follows:
# 1. The `title` will be the index
# 2. The `userId` will be the column
# 3. The `rating` will be the value

# %%
pivot = pd.pivot_table(df, index = 'title', columns = 'userId', values = 'rating')

# %%
pivot.head()
# Out:
# userId                                   1    2    3    4    5    6    7    \
# title
# '71 (2014)                               NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Hellboy': The Seeds of Creation (2004)  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Round Midnight (1986)                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Salem's Lot (2004)                      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Til There Was You (1997)                NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# userId                                   8    9    10   ...  601  602  603  \
# title                                                   ...
# '71 (2014)                               NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Hellboy': The Seeds of Creation (2004)  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Round Midnight (1986)                   NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Salem's Lot (2004)                      NaN  NaN  NaN  ...  NaN  NaN  NaN
# 'Til There Was You (1997)                NaN  NaN  NaN  ...  NaN  NaN  NaN
#
# userId                                   604  605  606  607  608  609  610
# title
# '71 (2014)                               NaN  NaN  NaN  NaN  NaN  NaN  4.0
# 'Hellboy': The Seeds of Creation (2004)  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Round Midnight (1986)                   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Salem's Lot (2004)                      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 'Til There Was You (1997)                NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 610 columns]

# %% [markdown]
# ## Creating a  sparse matrix
# ---
#
# In a minute, I'll calculate the cosine similarity for each movie using the `pairwise_distances` function. Before that, I need to create a sparse matrix (datatype) using `scipy`'s `sparse` module like so:
# ```python
# sparse.csr_matrix(pivot.fillna(0))
# ```

# %%
sparse_pivot = sparse.csr_matrix(pivot.fillna(0))

# %%
print(sparse_pivot)
# Out:
#   (0, 609)	4.0
#   (1, 331)	4.0
#   (2, 331)	3.5
#   (2, 376)	3.5
#   (3, 344)	5.0
#   (4, 112)	3.0
#   (4, 344)	5.0
#   (5, 20)	1.5
#   (6, 11)	5.0
#   (6, 18)	2.0
#   (6, 90)	2.0
#   (6, 94)	3.0
#   (6, 171)	4.0
#   (6, 216)	4.0
#   (6, 287)	3.0
#   (6, 293)	1.0
#   (6, 306)	3.5
#   (6, 376)	3.5
#   (6, 413)	3.0
#   (6, 473)	1.0
#   (6, 476)	3.5
#   (6, 519)	4.0
#   (6, 554)	5.0
#   (6, 560)	4.5
#   (6, 598)	2.0
#   :	:
#   (9717, 26)	5.0
#   (9717, 41)	5.0
#   (9717, 56)	2.0
#   (9717, 67)	4.0
#   (9717, 87)	3.5
#   (9717, 140)	3.5
#   (9717, 197)	2.0
#   (9717, 214)	2.5
#   (9717, 216)	2.0
#   (9717, 220)	3.5
#   (9717, 238)	3.0
#   (9717, 281)	4.0
#   (9717, 293)	4.0
#   (9717, 306)	2.5
#   (9717, 312)	1.0
#   (9717, 413)	3.0
#   (9717, 420)	3.0
#   (9717, 447)	3.0
#   (9717, 473)	3.0
#   (9717, 476)	3.5
#   (9717, 554)	3.0
#   (9717, 560)	4.0
#   (9717, 596)	3.0
#   (9717, 598)	2.5
#   (9718, 526)	1.0

# %% [markdown]
# ## Calculate cosine similarity
# ---
#
# `sklearn` has a built-in `pairwise_distances` function that we can use for our recommender. It will return a square matrix, comparing every movie with every other movie in the dataset.
#
# ```python
# pairwise_distances(sparse_pivot, metric='cosine')
# ```

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
pairwise_distances(sparse_pivot, metric='cosine')
# Out:
# array([[0.        , 1.        , 1.        , ..., 0.67267316, 1.        ,
#         1.        ],
#        [1.        , 0.        , 0.29289322, ..., 1.        , 1.        ,
#         1.        ],
#        [1.        , 0.29289322, 0.        , ..., 1.        , 1.        ,
#         1.        ],
#        ...,
#        [0.67267316, 1.        , 1.        , ..., 0.        , 1.        ,
#         1.        ],
#        [1.        , 1.        , 1.        , ..., 1.        , 0.        ,
#         1.        ],
#        [1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         0.        ]])

# %%
recommender = cosine_similarity(sparse_pivot)

# %% [markdown]
# ## Create distances DataFrame
# ---
#
# At this point, we essentially have a recommender. We'll load it into a `pandas` DataFrame for readability.
#
# You'll notice that each movie has a "distance" of 0 with itself (along the diagonal).

# %%
recommender_df = pd.DataFrame(recommender, columns = pivot.index, index = pivot.index)

recommender_df.head()
# Out:
# title                                    '71 (2014)  \
# title
# '71 (2014)                                      1.0
# 'Hellboy': The Seeds of Creation (2004)         0.0
# 'Round Midnight (1986)                          0.0
# 'Salem's Lot (2004)                             0.0
# 'Til There Was You (1997)                       0.0
#
# title                                    'Hellboy': The Seeds of Creation (2004)  \
# title
# '71 (2014)                                                              0.000000
# 'Hellboy': The Seeds of Creation (2004)                                 1.000000
# 'Round Midnight (1986)                                                  0.707107
# 'Salem's Lot (2004)                                                     0.000000
# 'Til There Was You (1997)                                               0.000000
#
# title                                    'Round Midnight (1986)  \
# title
# '71 (2014)                                             0.000000
# 'Hellboy': The Seeds of Creation (2004)                0.707107
# 'Round Midnight (1986)                                 1.000000
# 'Salem's Lot (2004)                                    0.000000
# 'Til There Was You (1997)                              0.000000
#
# title                                    'Salem's Lot (2004)  \
# title
# '71 (2014)                                          0.000000
# 'Hellboy': The Seeds of Creation (2004)             0.000000
# 'Round Midnight (1986)                              0.000000
# 'Salem's Lot (2004)                                 1.000000
# 'Til There Was You (1997)                           0.857493
#
# title                                    'Til There Was You (1997)  \
# title
# '71 (2014)                                                0.000000
# 'Hellboy': The Seeds of Creation (2004)                   0.000000
# 'Round Midnight (1986)                                    0.000000
# 'Salem's Lot (2004)                                       0.857493
# 'Til There Was You (1997)                                 1.000000
#
# title                                    'Tis the Season for Love (2015)  \
# title
# '71 (2014)                                                           0.0
# 'Hellboy': The Seeds of Creation (2004)                              0.0
# 'Round Midnight (1986)                                               0.0
# 'Salem's Lot (2004)                                                  0.0
# 'Til There Was You (1997)                                            0.0
#
# title                                    'burbs, The (1989)  \
# title
# '71 (2014)                                         0.000000
# 'Hellboy': The Seeds of Creation (2004)            0.000000
# 'Round Midnight (1986)                             0.176777
# 'Salem's Lot (2004)                                0.000000
# 'Til There Was You (1997)                          0.000000
#
# title                                    'night Mother (1986)  \
# title
# '71 (2014)                                                0.0
# 'Hellboy': The Seeds of Creation (2004)                   0.0
# 'Round Midnight (1986)                                    0.0
# 'Salem's Lot (2004)                                       0.0
# 'Til There Was You (1997)                                 0.0
#
# title                                    (500) Days of Summer (2009)  \
# title
# '71 (2014)                                                  0.141653
# 'Hellboy': The Seeds of Creation (2004)                     0.000000
# 'Round Midnight (1986)                                      0.000000
# 'Salem's Lot (2004)                                         0.000000
# 'Til There Was You (1997)                                   0.000000
#
# title                                    *batteries not included (1987)  ...  \
# title                                                                    ...
# '71 (2014)                                                          0.0  ...
# 'Hellboy': The Seeds of Creation (2004)                             0.0  ...
# 'Round Midnight (1986)                                              0.0  ...
# 'Salem's Lot (2004)                                                 0.0  ...
# 'Til There Was You (1997)                                           0.0  ...
#
# title                                    Zulu (2013)  [REC] (2007)  \
# title
# '71 (2014)                                       0.0      0.342055
# 'Hellboy': The Seeds of Creation (2004)          0.0      0.000000
# 'Round Midnight (1986)                           0.0      0.000000
# 'Salem's Lot (2004)                              0.0      0.000000
# 'Til There Was You (1997)                        0.0      0.000000
#
# title                                    [REC]² (2009)  \
# title
# '71 (2014)                                    0.543305
# 'Hellboy': The Seeds of Creation (2004)       0.000000
# 'Round Midnight (1986)                        0.000000
# 'Salem's Lot (2004)                           0.000000
# 'Til There Was You (1997)                     0.000000
#
# title                                    [REC]³ 3 Génesis (2012)  \
# title
# '71 (2014)                                              0.707107
# 'Hellboy': The Seeds of Creation (2004)                 0.000000
# 'Round Midnight (1986)                                  0.000000
# 'Salem's Lot (2004)                                     0.000000
# 'Til There Was You (1997)                               0.000000
#
# title                                    anohana: The Flower We Saw That Day - The Movie (2013)  \
# title
# '71 (2014)                                                                             0.0
# 'Hellboy': The Seeds of Creation (2004)                                                0.0
# 'Round Midnight (1986)                                                                 0.0
# 'Salem's Lot (2004)                                                                    0.0
# 'Til There Was You (1997)                                                              0.0
#
# title                                    eXistenZ (1999)  xXx (2002)  \
# title
# '71 (2014)                                           0.0    0.139431
# 'Hellboy': The Seeds of Creation (2004)              0.0    0.000000
# 'Round Midnight (1986)                               0.0    0.000000
# 'Salem's Lot (2004)                                  0.0    0.000000
# 'Til There Was You (1997)                            0.0    0.000000
#
# title                                    xXx: State of the Union (2005)  \
# title
# '71 (2014)                                                     0.327327
# 'Hellboy': The Seeds of Creation (2004)                        0.000000
# 'Round Midnight (1986)                                         0.000000
# 'Salem's Lot (2004)                                            0.000000
# 'Til There Was You (1997)                                      0.000000
#
# title                                    ¡Three Amigos! (1986)  \
# title
# '71 (2014)                                                 0.0
# 'Hellboy': The Seeds of Creation (2004)                    0.0
# 'Round Midnight (1986)                                     0.0
# 'Salem's Lot (2004)                                        0.0
# 'Til There Was You (1997)                                  0.0
#
# title                                    À nous la liberté (Freedom for Us) (1931)
# title
# '71 (2014)                                                                     0.0
# 'Hellboy': The Seeds of Creation (2004)                                        0.0
# 'Round Midnight (1986)                                                         0.0
# 'Salem's Lot (2004)                                                            0.0
# 'Til There Was You (1997)                                                      0.0
#
# [5 rows x 9719 columns]

# %% [markdown]
# ## Evaluate recommender performance
# ---
#
# Now comes the fun part! Let's check out a few movies to see if the recommender aligns with our intuition. In the cell below we'll do the following:
# 1. Create a search term
# 2. Use that to find all titles matching the search query
# 3. For each title, we'll list off the following:
#   1. The average rating
#   2. The number of ratings
#   3. The ten most similar movies

# %%
search = 'Die Hard'

#getting all the movies that have die hard in the title 
for title in movies.loc[movies['title'].str.contains(search), 'title']:
    print(title)
    
    print('Avg rating', pivot.loc[title, :].mean()) #avg rating for given movie 
    
    print('Count of ratings', pivot.T[title].count())
    
    print('')
    
    print('10 closest movies:')
    
    #getting 10 movies, index 0 is itself
    print(recommender_df[title].sort_values(ascending = False)[1:11])
    
    print('-----------------')
# Out:
# Die Hard: With a Vengeance (1995)
# Avg rating 3.5555555555555554
# Count of ratings 144
#
# 10 closest movies:
# title
# True Lies (1994)                     0.658258
# Speed (1994)                         0.634087
# Cliffhanger (1993)                   0.622068
# Ace Ventura: Pet Detective (1994)    0.618543
# GoldenEye (1995)                     0.615794
# Clear and Present Danger (1994)      0.600089
# Fugitive, The (1993)                 0.591703
# Batman (1989)                        0.586716
# Outbreak (1995)                      0.576947
# Batman Forever (1995)                0.576758
# Name: Die Hard: With a Vengeance (1995), dtype: float64
# -----------------
# Die Hard (1988)
# Avg rating 3.8620689655172415
# Count of ratings 145
#
# 10 closest movies:
# title
# Indiana Jones and the Last Crusade (1989)                                         0.663156
# Terminator, The (1984)                                                            0.643057
# Die Hard 2 (1990)                                                                 0.624657
# Star Wars: Episode V - The Empire Strikes Back (1980)                             0.615718
# Star Wars: Episode VI - Return of the Jedi (1983)                                 0.592980
# Indiana Jones and the Temple of Doom (1984)                                       0.591523
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.585940
# Matrix, The (1999)                                                                0.577811
# Back to the Future (1985)                                                         0.574321
# Saving Private Ryan (1998)                                                        0.572203
# Name: Die Hard (1988), dtype: float64
# -----------------
# Die Hard 2 (1990)
# Avg rating 3.4044117647058822
# Count of ratings 68
#
# 10 closest movies:
# title
# Die Hard (1988)                              0.624657
# Face/Off (1997)                              0.508140
# Batman Returns (1992)                        0.501400
# Air Force One (1997)                         0.493671
# Con Air (1997)                               0.487693
# Terminator, The (1984)                       0.486549
# Lethal Weapon (1987)                         0.478645
# Fifth Element, The (1997)                    0.476562
# Lethal Weapon 2 (1989)                       0.475862
# Indiana Jones and the Last Crusade (1989)    0.471964
# Name: Die Hard 2 (1990), dtype: float64
# -----------------
# Live Free or Die Hard (2007)
# Avg rating 3.40625
# Count of ratings 32
#
# 10 closest movies:
# title
# Transformers (2007)                                          0.535291
# King Kong (2005)                                             0.527905
# Phone Booth (2002)                                           0.510699
# Indiana Jones and the Kingdom of the Crystal Skull (2008)    0.507706
# Day After Tomorrow, The (2004)                               0.500460
# 300 (2007)                                                   0.499421
# Kick-Ass (2010)                                              0.496814
# Resident Evil: Afterlife (2010)                              0.493811
# Salt (2010)                                                  0.488660
# Terminator 3: Rise of the Machines (2003)                    0.488627
# Name: Live Free or Die Hard (2007), dtype: float64
# -----------------
# Good Day to Die Hard, A (2013)
# Avg rating 2.0833333333333335
# Count of ratings 6
#
# 10 closest movies:
# title
# Babes in Toyland (1934)       0.641689
# Vice (2015)                   0.641689
# Apollo 18 (2011)              0.641689
# Brubaker (1980)               0.641689
# Scorpio (1973)                0.641689
# Secretariat (2010)            0.641689
# Hope Springs (2003)           0.641689
# Hope Springs (2012)           0.641689
# Last Airbender, The (2010)    0.620344
# Larry Crowne (2011)           0.600832
# Name: Good Day to Die Hard, A (2013), dtype: float64
# -----------------

# %%
search = 'Twilight'

#getting all the movies that have die hard in the title 
for title in movies.loc[movies['title'].str.contains(search), 'title']:
    print(title)
    
    print('Avg rating', pivot.loc[title, :].mean()) #avg rating for given movie 
    
    print('Count of ratings', pivot.T[title].count())
    
    print('')
    
    print('10 closest movies:')
    
    #getting 10 movies, index 0 is itself
    print(recommender_df[title].sort_values(ascending = False)[1:11])
    
    print('----------------------')
# Out:
# Twilight (1998)
# Avg rating 2.3333333333333335
# Count of ratings 3
#
# 10 closest movies:
# title
# Damsels in Distress (2011)                                 0.759257
# Over the Garden Wall (2013)                                0.727607
# Jane Eyre (2011)                                           0.727607
# Janie Jones (2010)                                         0.727607
# Company Men, The (2010)                                    0.727607
# Sleepwalkers (1992)                                        0.727607
# Extraordinary Adventures of Adèle Blanc-Sec, The (2010)    0.727607
# Fulltime Killer (Chuen jik sat sau) (2001)                 0.727607
# Little Drummer Boy, The (1968)                             0.727607
# Funeral, The (1996)                                        0.727607
# Name: Twilight (1998), dtype: float64
# ----------------------
# Twilight Zone: The Movie (1983)
# Avg rating 3.0
# Count of ratings 3
#
# 10 closest movies:
# title
# From Paris with Love (2010)                                  0.927047
# Gonzo: The Life and Work of Dr. Hunter S. Thompson (2008)    0.925844
# Wizard, The (1989)                                           0.925132
# Machine Girl, The (Kataude mashin gâru) (2008)               0.913500
# Major League II (1994)                                       0.841682
# Killer Klowns from Outer Space (1988)                        0.840361
# Slumber Party Massacre, The (1982)                           0.829176
# Look Who's Talking Now (1993)                                0.825313
# Adventures of Huck Finn, The (1993)                          0.761830
# Ladybugs (1992)                                              0.758621
# Name: Twilight Zone: The Movie (1983), dtype: float64
# ----------------------
# Twilight Samurai, The (Tasogare Seibei) (2002)
# Avg rating 3.8333333333333335
# Count of ratings 6
#
# 10 closest movies:
# title
# Return, The (Vozvrashcheniye) (2003)                                            0.764277
# I Am a Fugitive from a Chain Gang (1932)                                        0.703596
# Ballad of Jack and Rose, The (2005)                                             0.631363
# Outfoxed: Rupert Murdoch's War on Journalism (2004)                             0.624584
# Nobody Knows (Dare mo shiranai) (2004)                                          0.599633
# Intimate Strangers (Confidences trop intimes) (2004)                            0.599323
# Assassination of Richard Nixon, The (2004)                                      0.596285
# Story of the Weeping Camel, The (Geschichte vom weinenden Kamel, Die) (2003)    0.596285
# Legend, The (Legend of Fong Sai-Yuk, The) (Fong Sai Yuk) (1993)                 0.558669
# Sword of Doom, The (Dai-bosatsu tôge) (1966)                                    0.556987
# Name: Twilight Samurai, The (Tasogare Seibei) (2002), dtype: float64
# ----------------------
# Twilight (2008)
# Avg rating 2.409090909090909
# Count of ratings 22
#
# 10 closest movies:
# title
# Twilight Saga: Breaking Dawn - Part 1, The (2011)    0.486089
# 17 Again (2009)                                      0.480746
# Priceless (Hors de prix) (2006)                      0.475986
# Confessions of a Shopaholic (2009)                   0.469168
# Pride & Prejudice (2005)                             0.468465
# Notebook, The (2004)                                 0.451679
# Twilight Saga: Eclipse, The (2010)                   0.414779
# Valentine's Day (2010)                               0.412947
# Twilight Saga: New Moon, The (2009)                  0.411625
# Agent Cody Banks (2003)                              0.411597
# Name: Twilight (2008), dtype: float64
# ----------------------
# Twilight Saga: New Moon, The (2009)
# Avg rating 2.6666666666666665
# Count of ratings 9
#
# 10 closest movies:
# title
# Priceless (Hors de prix) (2006)                      0.589853
# Twilight Saga: Breaking Dawn - Part 1, The (2011)    0.584620
# Twilight Saga: Eclipse, The (2010)                   0.578686
# Letters to Juliet (2010)                             0.506400
# New York, I Love You (2009)                          0.501507
# Coco Before Chanel (Coco avant Chanel) (2009)        0.481543
# Bride Wars (2009)                                    0.481543
# Like Crazy (2011)                                    0.467166
# Little Ashes (2008)                                  0.421350
# My Blueberry Nights (2007)                           0.421350
# Name: Twilight Saga: New Moon, The (2009), dtype: float64
# ----------------------
# Twilight Saga: Eclipse, The (2010)
# Avg rating 2.45
# Count of ratings 10
#
# 10 closest movies:
# title
# Twilight Saga: Breaking Dawn - Part 1, The (2011)    0.693325
# Bride Wars (2009)                                    0.674142
# Valentine's Day (2010)                               0.599906
# Twilight Saga: New Moon, The (2009)                  0.578686
# Priceless (Hors de prix) (2006)                      0.574449
# Holiday, The (2006)                                  0.570381
# Made of Honor (2008)                                 0.539847
# Julie & Julia (2009)                                 0.527045
# Princess Diaries 2: Royal Engagement, The (2004)     0.506356
# Family Stone, The (2005)                             0.480426
# Name: Twilight Saga: Eclipse, The (2010), dtype: float64
# ----------------------
# Twilight Saga: Breaking Dawn - Part 1, The (2011)
# Avg rating 2.2142857142857144
# Count of ratings 7
#
# 10 closest movies:
# title
# Priceless (Hors de prix) (2006)                      0.767546
# Bride Wars (2009)                                    0.704934
# Twilight Saga: Eclipse, The (2010)                   0.693325
# Twilight Saga: Breaking Dawn - Part 2, The (2012)    0.689776
# Coco Before Chanel (Coco avant Chanel) (2009)        0.626608
# Like Crazy (2011)                                    0.607899
# Valentine's Day (2010)                               0.601170
# Twilight Saga: New Moon, The (2009)                  0.584620
# Something Borrowed (2011)                            0.531363
# Family Stone, The (2005)                             0.496234
# Name: Twilight Saga: Breaking Dawn - Part 1, The (2011), dtype: float64
# ----------------------
# Twilight Saga: Breaking Dawn - Part 2, The (2012)
# Avg rating 1.875
# Count of ratings 4
#
# 10 closest movies:
# title
# Magic Mike XXL (2015)                                  0.744208
# Private Lives of Pippa Lee, The (2009)                 0.744208
# St Trinian's 2: The Legend of Fritton's Gold (2009)    0.744208
# Pretty One, The (2013)                                 0.744208
# Rust and Bone (De rouille et d'os) (2012)              0.744208
# The Hundred-Foot Journey (2014)                        0.744208
# Twilight Saga: Breaking Dawn - Part 1, The (2011)      0.689776
# How Do You Know (2010)                                 0.679869
# Best Exotic Marigold Hotel, The (2011)                 0.673294
# Made of Honor (2008)                                   0.672538
# Name: Twilight Saga: Breaking Dawn - Part 2, The (2012), dtype: float64
# ----------------------

# %%
search = 'Princess Bride'

#getting all the movies that have die hard in the title 
for title in movies.loc[movies['title'].str.contains(search), 'title']:
    print(title)
    
    print('Avg rating', pivot.loc[title, :].mean()) #avg rating for given movie 
    
    print('Count of ratings', pivot.T[title].count())
    
    print('')
    
    print('10 closest movies:')
    
    #getting 10 movies, index 0 is itself
    print(recommender_df[title].sort_values(ascending = False)[1:11])
    
    print('-----------------')
# Out:
# Princess Bride, The (1987)
# Avg rating 4.232394366197183
# Count of ratings 142
#
# 10 closest movies:
# title
# Monty Python and the Holy Grail (1975)                                            0.631292
# Star Wars: Episode V - The Empire Strikes Back (1980)                             0.602857
# Ferris Bueller's Day Off (1986)                                                   0.601883
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.595145
# Groundhog Day (1993)                                                              0.593322
# Back to the Future (1985)                                                         0.571364
# Star Wars: Episode IV - A New Hope (1977)                                         0.567963
# Indiana Jones and the Last Crusade (1989)                                         0.547876
# Star Wars: Episode VI - Return of the Jedi (1983)                                 0.543540
# Breakfast Club, The (1985)                                                        0.537991
# Name: Princess Bride, The (1987), dtype: float64
# -----------------

# %%
search = 'Shape of Water'

#getting all the movies that have die hard in the title 
for title in movies.loc[movies['title'].str.contains(search), 'title']:
    print(title)
    
    print('Avg rating', pivot.loc[title, :].mean()) #avg rating for given movie 
    
    print('Count of ratings', pivot.T[title].count())
    
    print('')
    
    print('10 closest movies:')
    
    #getting 10 movies, index 0 is itself
    print(recommender_df[title].sort_values(ascending = False)[1:11])
    
    print('-----------------')
# Out:
# The Shape of Water (2017)
# Avg rating 3.6875
# Count of ratings 8
#
# 10 closest movies:
# title
# I, Tonya (2017)                          0.605703
# The Edge of Seventeen (2016)             0.538383
# Isle of Dogs (2018)                      0.536358
# Untitled Spider-Man Reboot (2017)        0.525071
# Okja (2017)                              0.507349
# Angel's Egg (Tenshi no tamago) (1985)    0.507323
# Comic Book Villains (2002)               0.506856
# Jetée, La (1962)                         0.506856
# Man's Best Friend (1993)                 0.506225
# Dunkirk (2017)                           0.505933
# Name: The Shape of Water (2017), dtype: float64
# -----------------
